# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Data points for the first plot (without SMOTE)
X1 = [0.1104,
0.2112,
0.3184,
0.3380,
0.3440,
0.3824,
0.4130,
0.5900,
0.6908,
0.7558]

Y1 = [1,   
0.98,
0.95,
0.82,
1,
0.84,
0.95,
0.67,
0.8,
0.91]

# Data points for the second plot (BINARY-SMOTE)
X2 = [0.1104,
0.2112,
0.3184,
0.3380,
0.3440,
0.3824,
0.4130,
0.5900,
0.6908,
0.7558]
Y2 = [1,
0.98,
0.95,
0.82,
1,
0.84,
0.95,
0.77,
0.81,
0.93]


# Data points for the third plot (GRADIENT-SMOTE)
X3 = [0.1104,
0.2112,
0.3184,
0.3380,
0.3440,
0.3824,
0.4130,
0.5900,
0.6908,
0.7558]
Y3 = [1,
0.98,
0.95,
0.82,
1,
0.82,
0.95,
0.75,
0.82,
0.93]

# Create the plot
plt.figure(figsize=(8, 6))

# Plot the first set of data
sns.lineplot(x=X1, y=Y1, marker='o', label='Original Model', color='blue')

# Plot the second set of data
sns.lineplot(x=X2, y=Y2, marker='o', label='Binary-SMOTE', color='red')

# Plot the third set of data
sns.lineplot(x=X3, y=Y3, marker='o', label='Gradient-Smote', color='green')

# Add titles and labels
plt.title('AUC for diferent class imbalance levels')
plt.xlabel('Class Imbanlance')
plt.ylabel('AUC')

# Show legend
plt.legend()

# Show the plot
plt.show()
